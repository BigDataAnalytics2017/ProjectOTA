# %%
srch_id=[]
date_time=[]
site_id=[]
visitor_location_country_id=[]
visitor_hist_starrating=[]
visitor_hist_adr_usd=[]
prop_country_id=[]
prop_id=[]
prop_starrating=[]
prop_review_score=[]
prop_brand_bool=[]
prop_location_score1=[]
prop_location_score2=[]
prop_log_historical_price=[]
position=[]
price_usd=[]
promotion_flag=[]
srch_destination_id=[]
srch_length_of_stay=[]
srch_booking_window=[]
srch_adults_count=[]
srch_children_count=[]
srch_room_count=[]
srch_saturday_night_bool=[]
srch_query_affinity_score=[]
orig_destination_distance=[]
random_bool=[]
comp1_rate=[]
comp1_inv=[]
comp1_rate_percent_diff=[]
comp2_rate=[]
comp2_inv=[]
comp2_rate_percent_diff=[]
comp3_rate=[]
comp3_inv=[]
comp3_rate_percent_diff=[]
comp4_rate=[]
comp4_inv=[]
comp4_rate_percent_diff=[]
comp5_rate=[]
comp5_inv=[]
comp5_rate_percent_diff=[]
comp7_rate=[]
comp7_inv=[]
comp7_rate_percent_diff=[]
comp8_rate=[]
comp8_inv=[]
comp8_rate_percent_diff=[]
click_bool=[]
gross_bookings_usd=[]
booking_bool=[]

# %%
import csv
f = open('sample10000.csv', 'r')
for row in csv.reader(f):
    srch_id.append(row[0])
    date_time.append(row[1])
    site_id.append(row[2])
    visitor_location_country_id.append(row[3])
    visitor_hist_starrating.append(row[4])
    visitor_hist_adr_usd.append(row[5])
    prop_country_id.append(row[6])
    prop_id.append(row[7])
    prop_starrating.append(row[8])
    prop_review_score.append(row[9])
    prop_brand_bool.append(row[10])
    prop_location_score1.append(row[11])
    prop_location_score2.append(row[12])
    prop_log_historical_price.append(row[13])
    position.append(row[14])
    price_usd.append(row[15])
    promotion_flag.append(row[16])
    srch_destination_id.append(row[17])
    srch_length_of_stay.append(row[18])
    srch_booking_window.append(row[19])
    srch_adults_count.append(row[20])
    srch_children_count.append(row[21])
    srch_room_count.append(row[22])
    srch_saturday_night_bool.append(row[23])
    srch_query_affinity_score.append(row[24])
    orig_destination_distance.append(row[25])
    random_bool.append(row[26])
    comp1_rate.append(row[27])
    comp1_inv.append(row[28])
    comp1_rate_percent_diff.append(row[29])
    comp2_rate.append(row[30])
    comp2_inv.append(row[31])
    comp2_rate_percent_diff.append(row[32])
    comp3_rate.append(row[33])
    comp3_inv.append(row[34])
    comp3_rate_percent_diff.append(row[35])
    comp4_rate.append(row[36])
    comp4_inv.append(row[37])
    comp4_rate_percent_diff.append(row[38])
    comp5_rate.append(row[39])
    comp5_inv.append(row[40])
    comp5_rate_percent_diff.append(row[41])
    comp7_rate.append(row[42])
    comp7_inv.append(row[43])
    comp7_rate_percent_diff.append(row[44])
    comp8_rate.append(row[45])
    comp8_inv.append(row[46])
    comp8_rate_percent_diff.append(row[47])
    click_bool.append(row[48])
    gross_bookings_usd.append(row[49])
    booking_bool.append(row[50])
    print row
f.close()
# Out:
# ['75', '2013-05-04 19:20:52', '5', '219', 'NaN', 'NaN', '219', '128481', '4', '4.5', '0', '2.94', '0.0434', '5.31', '22', '155', '0', '17311', '1', '30', '3', '1', '1', '0', 'NaN', '318.52', '1', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', '1', '165', '1']
# ['129', '2013-01-16 06:56:51', '5', '35', 'NaN', 'NaN', '35', '113858', '3', '3.5', '0', '3.85', '0.1993', '4.26', '8', '44', '1', '21207', '2', '1', '1', '0', '1', '1', 'NaN', 'NaN', '0', 'NaN', 'NaN', 'NaN', '0', '0', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', '0', 'NaN', '0']
# ...

# %%
gross_bookings_usd
# Out:
# ['NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  '1',
#  '0',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  'NaN',
#  '0',
#  '0',
#  '1',
#  '0',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  'NaN',
#  'NaN',
#  '0',
#  '0',
#  'NaN',
#  'NaN',
#  '0',
#  'NaN',
#  '0',
#  'NaN',
#  'NaN',
# ...

# %%
date_time
# Out:
# ['2013-05-04 19:20:52',
#  '2013-01-16 06:56:51',
#  '2012-12-11 07:15:29',
#  '2012-11-01 14:06:25',
#  '2013-06-11 21:49:52',
#  '2013-02-06 19:51:54',
#  '2013-03-13 13:09:38',
#  '2013-06-26 09:38:51',
#  '2013-05-29 06:02:18',
#  '2013-03-01 10:32:23',
#  '2013-06-07 22:33:31',
#  '2013-02-08 14:32:01',
#  '2012-12-04 08:04:17',
#  '2013-02-11 11:10:45',
#  '2013-05-23 06:07:22',
#  '2013-04-10 04:07:40',
#  '2013-03-12 16:33:55',
#  '2013-02-06 12:00:40',
#  '2012-11-17 12:17:38',
#  '2013-05-15 15:07:45',
#  '2012-12-26 15:13:55',
#  '2012-11-13 18:14:31',
#  '2013-02-01 19:17:17',
#  '2013-05-16 12:06:26',
#  '2013-04-29 09:43:34',
#  '2013-02-10 16:48:52',
#  '2013-06-27 20:35:20',
#  '2013-01-15 19:07:51',
#  '2013-01-25 15:51:23',
#  '2013-04-15 13:22:00',
#  '2012-12-28 16:34:38',
#  '2013-05-23 08:20:46',
#  '2012-12-08 19:32:57',
#  '2013-03-19 11:42:20',
#  '2013-04-01 08:07:31',
#  '2013-01-22 17:53:06',
#  '2013-03-29 15:01:05',
#  '2013-04-07 22:42:16',
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pandas as pd

# %%
import numpy as np

# %%
gross_bookings_usd[:] = [float(x) for x in gross_bookings_usd]

# %%
s = pd.Series(gross_bookings_usd)
print s.isnull()
print
print s[s.isnull()]
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12    False
# 13     True
# 14     True
# ...
# 10002     True
# 10003    False
# 10004     True
# 10005     True
# 10006    False
# 10007     True
# 10008     True
# 10009     True
# 10010    False
# 10011     True
# 10012    False
# 10013     True
# 10014    False
# 10015     True
# 10016     True
# Length: 10017, dtype: bool
#
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 11   NaN
# 13   NaN
# 14   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# ...
# 9993    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 10000   NaN
# 10002   NaN
# 10004   NaN
# 10005   NaN
# 10007   NaN
# 10008   NaN
# 10009   NaN
# 10011   NaN
# 10013   NaN
# 10015   NaN
# 10016   NaN
# Length: 5917, dtype: float64

# %%
gross_bookings_usd[:] = [float(x) for x in prop_review_score]

# %%
s = pd.Series(prop_review_score)
print s.isnull()
print
print s[s.isnull()]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 10002    False
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# 10008    False
# 10009    False
# 10010    False
# 10011    False
# 10012    False
# 10013    False
# 10014    False
# 10015    False
# 10016    False
# Length: 10017, dtype: bool
#
# Series([], dtype: object)

# %%
plot(prop_review_score,gross_bookings_usd)

# %%
from scipy.optimize import curve_fit
